# %% [markdown]
# 1. Find the val%e of T(2) for the rec%rrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5.

# %% [markdown]
# Ans :
#
#     T(n) =3T(n-1) +12n
#     T(1) =3T(1-1) +12*1
#     T(1) =3T(0) +12
#     T(1) =3*5 + 12
#     T(1) =15 +12
#     "T(1) =27"
#
#     T(2) =3T(n-1) +12n
#     T(2) =3T(2-1) +12*2
#     T(2) =3T(1) +24
#     T(2) =3*27(1) +24
#     T(2) =81 +24
#     T(2) =105
#
#     So, the value of (2)T(2) is 105 for the given recurrence relation
#
#
#
# T(n)=3T(n−1)+12n with the initial condition
# �
# (
# 0
# )
# =
# 5
# T(0)=5.

# %% [markdown]
# 2. Given a rec%rrence relation, solve it %sing the s%bstit%tion method:
# a. T(n) = T(n-1) + c
# b. T(n) = 2T(n/2) + n
# c. T(n) = 2T(n/2) + c
# d. T(n) = T(n/2) + c

# %% [markdown]
# `T(n) = T(n-1) + c`

# %% [markdown]
# Ans :
#
#     T(n) =T(n-1) +C ====> Thise is main Equation(1)
#     # Substitute Value
#     T(n-1) =T(n-1)-1 + C
#     T(n-1) =T(n-2) + C +C
#     #put T(n-1) in main Equation
#
#     T(n) =T(n-2)+ 2C ====> Equation No (2)
#
#     #Substitute Value t(n) =T(n-2)
#     T(n-2) =T(n-2)-1 +2C
#
#     # Put Value T(n-2)in Eq(2)
#     T(n) =T(n-3)+3C
#
#     # there we continue till k time we got equation
#     T(n) =T(n-k)+K
#     So, n-k =0 therefore n=k
#
#     T(n) =T(n-n) + n
#     T(n) =T(0) + n
#     # So, Value of T(0) =1
#
#     T(n) =1 + n

# %% [markdown]
# `b. T(n) = 2T(n/2) + n`

# %% [markdown]
# Ans:
#
#     T(n)=2T(n/2) +n  =======> Equation no 1
#     # Substitute t(n) in place of (n/2)
#     T(n/2) =2T(n/2*2) +n/2
#     T(n)= 2*2T(n/2*2) +2n  =========Equation no 2
#     # Substitute value n/2*2 in Eq (2)
#
#     T(n/2*2) =2*2{2T(n/2*3)+n/2*2} +2n
#     T(n) =2*3 T(n/2*3)+ 3n ======> Equation 3
#     # until K time
#     T(n) =2*k T(n/2*k) +kn
#     #Assume
#     T(n/2*k) =T(1)
#     n/2*k =1
#     n= 2*k
#     k =log n
#
#     # Put values in eq
#     T(n) =2*k T(1) +kn
#     T(n) =n *1 + log n

# %% [markdown]
# `c. T(n) = 2T(n/2) + c`

# %% [markdown]
# Ans :
#
#     T(n)= 2T(n/2) +C ======>Eqaution No 1
#     T(n/2) =2T(n/4) +(n/2)  ==========1.1
#     T(n/4) =2T(n/8) +(n/4)  ==========1.2
#
#     # put n/2 value in (1)
#     T(n) =2{2T (n/4) +(n/2)}+C
#     T(n) =2*2 T(n/4) +C +C
#     T(n)=2*2 T(n/4) +2C ===== Equation(2)
#
#     # substitute n/4 values in eq 1.1
#     T(n) =2{2T(n/8)+(n/4)}+2C
#     T(n) =2*3 T(n/8) +3C ======Equation (3)
#
#     # Until K time
#     2*k T(n/2*k) + K.n
#     n/2*k =1 so n=2*k
#     log n =log 2*k
#     log n =k

# %% [markdown]
# `d. T(n) = T(n/2) + c`

# %% [markdown]
# Ans :
#
#     T(n)= T(n/2) +C  =====> eq no 1
#     # Put T(n/2) in place ofg T(n)
#     T(n/2) =T(n/4) +C  =====>Eq no 2.1
#     #put T(n/4) in place of T(n/2)
#     T(n/4) =T(n/8) +C ==== Eq no 3.1
#
#     # Put Eq 2  Value in Eq 1
#     T(n) ={T(n/4)+C} +C
#     T(n) =T(n/4) +2C  ====> (2)
#
#     # Put Eq 3  Value in Eq 2
#     T(n) ={T(n/8) +C}+2C
#     T(n) =T(n/8) +3C
#
#     # Untill We go to k times So the equation is
#     T(n) =T(n/k) +k.C
#     t(1) =1
#     n =2k
#     T(n) =T(n/n)+K.C
#     T(n) =1 +k.C
#
#     1 + log n .C
#     = Olog2 n

# %% [markdown]
# 3. Given a rec%rrence relation, solve it %sing the rec%rsive tree approach:

# %% [markdown]
# a. T(n) = 2T(n-1) +1

# %% [markdown]
# ![Recursive tree.png](attachment:690ab2ba-b526-4798-bb59-7acbc81b7cb7.png)

# %% [markdown]
# 1 + 2^1 +2^2 +2^3 +......+2^k   =2^ k+1 -1
#
# a + ar +ar^2 +ar^3 + .......+ar^k =
#
# a(r^k+1) -1 /r-1
# a=1 ,r=2
#
# = 1(2^k+1) -1 /2-1
# = 2^(k+1)-1

# %% [markdown]
# `b. T(n) = 2T(n/2) + n`

# %% [markdown]
# ![Recursive.JPG](attachment:bc0e0d36-bf48-4833-9baf-ea5035a85732.JPG)

# %% [markdown]
# ### Untill Kth time
# T(n) ={1  n=1
#       T(n) =2T(n/2)+n }
#  so n/2^k  =1
#     n =2^k
#
#     k =log n
#
#  final = O n log n
